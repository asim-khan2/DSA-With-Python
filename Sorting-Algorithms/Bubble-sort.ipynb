# %% [markdown]
# Bubble Sort is a sorting algorithm that repeatedly compares
# adjacent elements and swaps them if they are in the wrong order,
# until the list becomes sorted.

# %%
## Bubble sort Algorithm

def bubble_sort(arr):
    l = len(arr) ## length of the nums

    for i in range(l-1):
        for j in range(l-i-1):
            if arr[j] > arr[j+1]:
                arr[j],arr[j+1] = arr[j+1],arr[j]

# %%
arr = [2,3,4,5,8,1]
bubble_sort(arr)
print(f"After sorted array is {arr}")
# Out:
# After sorted array is [1, 2, 3, 4, 5, 8]
